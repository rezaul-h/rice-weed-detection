# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10983559223444300061
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10081009664
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10104166420874886385
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %% [markdown]
# **Importing the necessary packages**

# %%
import numpy as np 
import pandas as pd
import os
from sklearn.metrics import *
from sklearn.preprocessing import LabelBinarizer
# import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import *

# specifically for cnn
from tensorflow.keras.layers import Dropout, Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization,MaxPool2D,GlobalAveragePooling2D
 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import seaborn as sns
# import cv2
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# **Reading the image files**

# %%
dire= 'F:\\Ml files\\Weed detection\\flower recognition\\data\\FINAL DATASET'
categories=['Alternanthera philoxeroide', 'Centella asiatica', 'Commelina benghalensis',
            'Cyperus ochraceus', 'Fimbristylis littoralis', 'Ipomoea aquatic',
            'Marsilea minuta', 'Panicum repens', 'Paspalum scrobiculatum',
            'Pteris vittata', 'Synedrella nodiflora']

# %%
features=[]

for i in tqdm(categories):
    path=os.path.join(dire,i)
    num_classes=categories.index(i)
    for img in os.listdir(path):
        if img.endswith('.jpg'): 
            img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_COLOR)
            img_array=cv2.resize(img_array,(150,150))
            features.append([img_array,num_classes])

# %%
X=[]
y=[]
for i,j in features:
    X.append(i)
    y.append(j)

# %% [markdown]
# **Example of flower images per class**

# %%
fig,ax=plt.subplots(2,5)
fig.set_size_inches(15,15)
for i in range(2):
    for j in range (5):
        l=np.random.randint(0,len(y))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+categories[y[l]])
plt.axis('off')        
plt.tight_layout()

# %% [markdown]
# Reshaping and normalizing: the need of resizing the feature vetcor x is to meet the keras requirement and normalization is done to scale all the values in a similar range¶

# %%
X=np.array(X).reshape(-1,150,150,3)/255.0

# %% [markdown]
# **Class destribution**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(14,7))
fig=sns.countplot(y)
fig.set(xticks=range(len(categories)), xticklabels=[i for i in categories])
plt.xlabel('FLOWER SPECIES')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
list_dandelion=len([i for i in y if i==0])
list_daisy=len([i for i in y if i==1])
list_sunflower=len([i for i in y if i==2])
list_tulip=len([ i for i in y if i==3])
list_rose=len([i for i in y if i==4])
list_species=[list_dandelion,list_daisy,list_sunflower,list_tulip,list_rose]

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(18,10))
plt.pie(list_species,labels=categories,startangle=90,colors=['r','g','b','y','m'],autopct='%1.1f%%',explode = (0, 0.1, 0, 0,0),shadow=True)
plt.legend()
plt.show()

# %%
from tensorflow.keras.utils import to_categorical
y=to_categorical(y)

# %% [markdown]
# **Train Test split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=12)

# %% [markdown]
# **CNN Model**

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(150,150,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same"))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same"))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(2, 2, padding="same"))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(512, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(5, activation="softmax"))

# %% [markdown]
# **Augmentation to avoid overfitting**

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
datagen.fit(x_train)

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  activation_1 (Activation)   (None, 72, 72, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  activation_2 (Activation)   (None, 34, 34, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 128)       0
#
#  flatten (Flatten)           (None, 36992)             0
#
#  dense (Dense)               (None, 512)               18940416
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 19,099,973
# Trainable params: 19,099,973
# Non-trainable params: 0
# _________________________________________________________________

# %%
# !pip3 install ann_visualizer
# !pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ann_visualizer
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
# Building wheels for collected packages: ann-visualizer
#   Building wheel for ann-visualizer (setup.py) ... done
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=41d0f4728920c357efa5e88470ac69646c499e6c1ab33d2d849c85b1ae1b9450
#   Stored in directory: /root/.cache/pip/wheels/1b/fc/58/2ab1c3b30350105929308becddda4fb59b1358e54f985e1f4a
# Successfully built ann-visualizer
# Installing collected packages: ann-visualizer
# Successfully installed ann-visualizer-2.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (0.10.1)

# %%
from ann_visualizer.visualize import ann_viz
from graphviz import Source

# %%
ann_viz(model, view=True, title="CNN architecture")
Source.from_file('network.gv')

# %%
keras.backend.clear_session()
#callback function for early stopping
class myCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
      if(logs.get('accuracy')>99.99):
        print("\nReached %2.2f%% accuracy so we will stop trianing" % (accuracy_threshold*100))
        self.model.stop_training = True

acc_callback = myCallback()

# %%
checkpoint_path = '/content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5'
epochs=50

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

# %%
CNN_history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=128),
                              epochs = epochs, validation_data = (x_test,y_test),
                              callbacks=callbacks,
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# Epoch 1/50
# 22/22 [==============================] - ETA: 0s - loss: 2.0648 - accuracy: 0.2318
# Epoch 1: val_loss improved from inf to 1.60742, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 32s 988ms/step - loss: 2.0648 - accuracy: 0.2318 - val_loss: 1.6074 - val_accuracy: 0.2711 - lr: 0.0010
# Epoch 2/50
# 22/22 [==============================] - ETA: 0s - loss: 1.5970 - accuracy: 0.2447
# Epoch 2: val_loss improved from 1.60742 to 1.53711, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 16s 730ms/step - loss: 1.5970 - accuracy: 0.2447 - val_loss: 1.5371 - val_accuracy: 0.3065 - lr: 0.0010
# Epoch 3/50
# 22/22 [==============================] - ETA: 0s - loss: 1.4646 - accuracy: 0.3536
# Epoch 3: val_loss improved from 1.53711 to 1.25878, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 15s 674ms/step - loss: 1.4646 - accuracy: 0.3536 - val_loss: 1.2588 - val_accuracy: 0.4837 - lr: 0.0010
# Epoch 4/50
# 22/22 [==============================] - ETA: 0s - loss: 1.3217 - accuracy: 0.4184
# Epoch 4: val_loss improved from 1.25878 to 1.18203, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 15s 690ms/step - loss: 1.3217 - accuracy: 0.4184 - val_loss: 1.1820 - val_accuracy: 0.4619 - lr: 0.0010
# Epoch 5/50
# 22/22 [==============================] - ETA: 0s - loss: 1.2440 - accuracy: 0.4509
# Epoch 5: val_loss improved from 1.18203 to 1.13043, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 16s 731ms/step - loss: 1.2440 - accuracy: 0.4509 - val_loss: 1.1304 - val_accuracy: 0.4986 - lr: 0.0010
# Epoch 6/50
# 22/22 [==============================] - ETA: 0s - loss: 1.1775 - accuracy: 0.5089
# Epoch 6: val_loss improved from 1.13043 to 1.10908, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 18s 821ms/step - loss: 1.1775 - accuracy: 0.5089 - val_loss: 1.1091 - val_accuracy: 0.5545 - lr: 0.0010
# Epoch 7/50
# 22/22 [==============================] - ETA: 0s - loss: 1.1411 - accuracy: 0.5306
# Epoch 7: val_loss improved from 1.10908 to 1.03259, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 15s 669ms/step - loss: 1.1411 - accuracy: 0.5306 - val_loss: 1.0326 - val_accuracy: 0.5967 - lr: 0.0010
# Epoch 8/50
# 22/22 [==============================] - ETA: 0s - loss: 1.1262 - accuracy: 0.5591
# Epoch 8: val_loss improved from 1.03259 to 0.99709, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 15s 685ms/step - loss: 1.1262 - accuracy: 0.5591 - val_loss: 0.9971 - val_accuracy: 0.6022 - lr: 0.0010
# Epoch 9/50
# 22/22 [==============================] - ETA: 0s - loss: 1.0638 - accuracy: 0.5749
# Epoch 9: val_loss improved from 0.99709 to 0.93373, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/cnn.h5
# 22/22 [==============================] - 17s 775ms/step - loss: 1.0638 - accuracy: 0.5749 - val_loss: 0.9337 - val_accuracy: 0.6240 - lr: 0.0010
# Epoch
50
# 22/22 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.8141
# Epoch 48: val_loss did not improve from 0.56057
# 22/22 [==============================] - 13s 590ms/step - loss: 0.5135 - accuracy: 0.8141 - val_loss: 0.5840 - val_accuracy: 0.7888 - lr: 1.0000e-04
# Epoch 49/50
# 22/22 [==============================] - ETA: 0s - loss: 0.5065 - accuracy: 0.8120
# Epoch 49: val_loss did not improve from 0.56057
# 22/22 [==============================] - 13s 598ms/step - loss: 0.5065 - accuracy: 0.8120 - val_loss: 0.5821 - val_accuracy: 0.7861 - lr: 1.0000e-04
# Epoch 50/50
# 22/22 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.8031
# Epoch 50: val_loss did not improve from 0.56057
# 22/22 [==============================] - 13s 610ms/step - loss: 0.5176 - accuracy: 0.8031 - val_loss: 0.5814 - val_accuracy: 0.7956 - lr: 1.0000e-04

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(CNN_history.history['loss'])
plt.plot(CNN_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(CNN_history.history['accuracy'])
plt.plot(CNN_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
preds=model.predict(x_test)
predictions=np.argmax(preds,axis=1)
# Out:
# 23/23 [==============================] - 1s 16ms/step

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.85       186
#            1       0.78      0.80      0.79       121
#            2       0.77      0.92      0.84       138
#            3       0.82      0.67      0.74       155
#            4       0.72      0.77      0.74       134
#
#     accuracy                           0.80       734
#    macro avg       0.79      0.80      0.79       734
# weighted avg       0.80      0.80      0.79       734

# %%
def report_generate(Y_test, predictions):
  report = pd.DataFrame(classification_report(y_true = Y_test, y_pred = predictions, output_dict=True)).transpose()
  report = report.rename(index={'0': 'dandelion','1':'daisy','2':'sunflowers','3':'tulips', '4':'roses'})
  report[['precision','recall','f1-score']]=report[['precision','recall','f1-score']].apply(lambda x: round(x*100,2))
  report=report.drop(["support"],axis=1)
  columns = ['precision','recall','f1-score']
  report.columns = columns
  plt = report.plot(kind='bar',figsize=(12,6))
  
  plot=plt.tick_params(rotation=40)
  
  return plot,report

# %%
report_generate(Y_test, predictions)
# Out:
# (None,               precision  recall  f1-score
#  dandelion         86.93   82.26     84.53
#  daisy             78.23   80.17     79.18
#  sunflowers        77.44   92.03     84.11
#  tulips            81.89   67.10     73.76
#  roses             72.03   76.87     74.37
#  accuracy          79.56   79.56     79.56
#  macro avg         79.30   79.68     79.19
#  weighted avg      79.93   79.56     79.44)

# %%
#confusion matrix
def conf_matrix(Y_test, y_pred):

  cm = confusion_matrix(Y_test, y_pred) 
# Transform to df for easier plotting
  
  cm_df = pd.DataFrame(cm,
                       index = ['dandelion', 'daisy', 'sunflowers', 'tulips', 'roses'], 
                       columns = ['dandelion', 'daisy', 'sunflowers', 'tulips', 'roses'])
  plt.figure(figsize=(10,7))
  sns.heatmap(cm_df, annot=True,cmap="YlGnBu", fmt='g')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.xticks(rotation = 45)
  plt.yticks(rotation = 45)
  plt.show()
  plt.close()

# %%
conf_matrix(Y_test,predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.8729660506166317

# %%
correct_class=[]
incorrect_class=[]
i=0
for i in range(len(y_test)):
    if(np.argmax(y_test[i])==predictions[i]):
        correct_class.append(i)
    if(len(correct_class)==8):
        break

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[correct_class[count]])
        ax[i,j].set_title("Predicted Flower : "+ categories[predictions[correct_class[count]]] +"\n"+"Actual Flower : "+ categories[np.argmax(y_test[correct_class[count]])])
        plt.tight_layout()
        count+=1

# %%
i=0
for i in range(len(y_test)):
    
    if (np.argmax(y_test[i])!=predictions[i]):
        
        incorrect_class.append(i)
    if (len(incorrect_class)==8):
        break

# %%
count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range(4):
    for j in range(2):
        ax[i,j].imshow(x_test[incorrect_class[count]])
        ax[i,j].set_title("Predicted flower : " + categories[predictions[incorrect_class[count]]] + "\n"+"Actual Flower : " +categories[np.argmax(y_test[incorrect_class[count]])])
        plt.tight_layout()
        count+=1

# %%
import requests
from PIL import Image
from io import BytesIO

def process_image(url):
    response=requests.get(url)
    img=Image.open(BytesIO(response.content))
    fix,ax=plt.subplots(1,3,figsize=(15,20))
    ax[0].imshow(img)
    ax[0].set_title('image')
    
    #grayscale and normalization
    img=np.array(img)
    img=cv2.cvtColor(img,cv2.IMREAD_COLOR)
    print(img.shape)
    img=img/255.0
    ax[1].imshow(img)
    ax[1].set_title('color image')
    
    #resizing
    img=cv2.resize(img,(150,150))
    print(img.shape)
    ax[2].imshow(img)
    ax[2].set_title('predicted image')
    plt.tight_layout()
    img=np.expand_dims(img,axis=0)
    #making it model ready
    
    print(img.shape)
    return img


    
def predict(url):
    img=process_image(url)
    label=model.predict(img)
    final_1=np.argmax(label,axis=1)[0]
    plt.xlabel(categories[final_1])
    return categories[final_1]

# %%
predict("https://images.pexels.com/photos/1883385/pexels-photo-1883385.jpeg?auto=compress&cs=tinysrgb&w=600")
# Out:
# (900, 600, 3)
# (150, 150, 3)
# (1, 150, 150, 3)
# 1/1 [==============================] - 0s 19ms/step
# 'tulips'

# %% [markdown]
# **VGG16 Model**

# %%
from keras.applications import VGG16
Base_model = VGG16(include_top= False, weights='imagenet',input_shape=(150,150,3), pooling='avg')
VGG16_model = Sequential()

VGG16_model.add(Base_model)
VGG16_model.add(Dense(256,activation='relu'))
# adding prediction(softmax) layer
VGG16_model.add(Dense(5,activation="softmax"))
VGG16_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 14,847,301
# Trainable params: 14,847,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
VGG16_model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
checkpoint_path = '/content/drive/MyDrive/Colab Notebooks/flower recognition/VGG16.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

VGG16_history = VGG16_model.fit_generator(datagen.flow(x_train,y_train, batch_size=128),
                              epochs = 100, validation_data = (x_test,y_test),
                              callbacks=callbacks,
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if sys.path[0] == '':
# Epoch 1/100
#  6/22 [=======>......................] - ETA: 13s - loss: 2.9940 - accuracy: 0.2253
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.3320s vs `on_train_batch_end` time: 0.4008s). Check your callbacks.
# 22/22 [==============================] - ETA: 0s - loss: 1.9798 - accuracy: 0.2447
# Epoch 1: val_loss improved from inf to 1.56462, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/VGG16.h5
# 22/22 [==============================] - 60s 2s/step - loss: 1.9798 - accuracy: 0.2447 - val_loss: 1.5646 - val_accuracy: 0.3501 - lr: 0.0010
# Epoch 2/100
# 22/22 [==============================] - ETA: 0s - loss: 1.5316 - accuracy: 0.3066
# Epoch 2: val_loss improved from 1.56462 to 1.46910, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/VGG16.h5
# 22/22 [==============================] - 22s 975ms/step - loss: 1.5316 - accuracy: 0.3066 - val_loss: 1.4691 - val_accuracy: 0.3311 - lr: 0.0010
# Epoch 3/100
# 22/22 [==============================] - ETA: 0s - loss: 1.3138 - accuracy: 0.4306
# Epoch 3: val_loss improved from 1.46910 to 1.22597, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/VGG16.h5
# 22/22 [==============================] -
100
# 22/22 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9466
# Epoch 56: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 935ms/step - loss: 0.1476 - accuracy: 0.9466 - val_loss: 0.4661 - val_accuracy: 0.8638 - lr: 1.0000e-05
# Epoch 57/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9434
# Epoch 57: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 926ms/step - loss: 0.1472 - accuracy: 0.9434 - val_loss: 0.4701 - val_accuracy: 0.8638 - lr: 1.0000e-05
# Epoch 58/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1460 - accuracy: 0.9427
# Epoch 58: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 924ms/step - loss: 0.1460 - accuracy: 0.9427 - val_loss: 0.4725 - val_accuracy: 0.8638 - lr: 1.0000e-05
# Epoch 59/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9512
# Epoch 59: val_loss did not improve from 0.43999
# 22/22 [==============================] - 22s 978ms/step - loss: 0.1424 - accuracy: 0.9512 - val_loss: 0.4704 - val_accuracy: 0.8597 - lr: 1.0000e-05
# Epoch 60/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9480
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 60: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 919ms/step - loss: 0.1390 - accuracy: 0.9480 - val_loss: 0.4718 - val_accuracy: 0.8597 - lr: 1.0000e-05
# Epoch 61/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9484
# Epoch 61: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 926ms/step - loss: 0.1419 - accuracy: 0.9484 - val_loss: 0.4718 - val_accuracy: 0.8597 - lr: 1.0000e-06
# Epoch 62/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9476
# Epoch 62: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 921ms/step - loss: 0.1482 - accuracy: 0.9476 - val_loss: 0.4720 - val_accuracy: 0.8597 - lr: 1.0000e-06
# Epoch 63/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9512
# Epoch 63: val_loss did not improve from 0.43999
# 22/22 [==============================] - 22s 985ms/step - loss: 0.1461 - accuracy: 0.9512 - val_loss: 0.4721 - val_accuracy: 0.8597 - lr: 1.0000e-06
# Epoch 64/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9516
# Epoch 64: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 915ms/step - loss: 0.1386 - accuracy: 0.9516 - val_loss: 0.4728 - val_accuracy: 0.8597 - lr: 1.0000e-06
# Epoch 65/100
# 22/22 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9487
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 65: val_loss did not improve from 0.43999
# 22/22 [==============================] - 21s 920ms/step - loss: 0.1430 - accuracy: 0.9487 - val_loss: 0.4732 - val_accuracy: 0.8583 - lr: 1.0000e-06
# Epoch 65: early stopping

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(VGG16_history.history['loss'])
plt.plot(VGG16_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(VGG16_history.history['accuracy'])
plt.plot(VGG16_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
vgg_preds=VGG16_model.predict(x_test)
VGG16_model_predictions=np.argmax(vgg_preds,axis=1)
# Out:
# 23/23 [==============================] - 2s 78ms/step

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, VGG16_model_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       186
#            1       0.90      0.91      0.91       121
#            2       0.91      0.90      0.91       138
#            3       0.81      0.81      0.81       155
#            4       0.77      0.84      0.80       134
#
#     accuracy                           0.86       734
#    macro avg       0.86      0.86      0.86       734
# weighted avg       0.86      0.86      0.86       734

# %%
report_generate(Y_test, VGG16_model_predictions)
# Out:
# (None,               precision  recall  f1-score
#  dandelion         90.80   84.95     87.78
#  daisy             90.16   90.91     90.53
#  sunflowers        91.18   89.86     90.51
#  tulips            80.77   81.29     81.03
#  roses             76.71   83.58     80.00
#  accuracy          85.83   85.83     85.83
#  macro avg         85.93   86.12     85.97
#  weighted avg      86.08   85.83     85.90)

# %%
conf_matrix(Y_test,VGG16_model_predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,VGG16_model_predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9128440817555962
