# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6575242144133094946
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 10994067712
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6475489644242742197
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6"
# ]

# %% [markdown]
# **Importing the necessary packages**

# %%
import numpy as np 
import pandas as pd
import os
from sklearn.metrics import *
from sklearn.preprocessing import LabelBinarizer
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import *

# specifically for cnn
from tensorflow.keras.layers import Dropout, Flatten,Activation
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization,MaxPool2D,GlobalAveragePooling2D
 
from keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt
import seaborn as sns
import cv2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11304/3613085802.py in <module>
#       5 from sklearn.preprocessing import LabelBinarizer
#       6 from tensorflow import keras
# ----> 7 from keras import backend as K
#       8 from keras.models import Sequential,Model
#       9 from keras.layers import Dense
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\__init__.py in <module>
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\utils\__init__.py in <module>
#      24 from .layer_utils import get_source_inputs
#      25 from .layer_utils import print_summary
# ---> 26 from .vis_utils import model_to_dot
#      27 from .vis_utils import plot_model
#      28 from .np_utils import to_categorical
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\utils\vis_utils.py in <module>
#       5
#       6 import os
# ----> 7 from ..models import Model
#       8 from ..layers.wrappers import Wrapper
#       9
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\models.py in <module>
#       8 from .utils.generic_utils import has_arg
#       9 from .utils.generic_utils import to_list
# ---> 10 from .engine.input_layer import Input
#      11 from .engine.input_layer import InputLayer
#      12 from .engine.training import Model
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\engine\__init__.py in <module>
#       1 # note: `Node` is an internal class,
#       2 # it isn't meant to be used by Keras users.
# ----> 3 from .input_layer import Input
#       4 from .input_layer import InputLayer
#       5 from .base_layer import InputSpec
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\engine\input_layer.py in <module>
#       5 from __future__ import division
#       6
# ----> 7 from .base_layer import Layer
#       8 from .base_layer import Node
#       9 from .. import backend as K
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\engine\base_layer.py in <module>
#      10
#      11 from .. import backend as K
# ---> 12 from .. import initializers
#      13 from ..utils.layer_utils import count_params
#      14 from ..utils.generic_utils import has_arg
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\initializers\__init__.py in <module>
#     122 # from ALL_OBJECTS. We make no guarantees as to whether these objects will
#     123 # using their correct version.
# --> 124 populate_deserializable_objects()
#     125 globals().update(LOCAL.ALL_OBJECTS)
#     126
#
# ~\anaconda3\envs\tensrgpu\lib\site-packages\keras\initializers\__init__.py in populate_deserializable_objects()
#      47
#      48   LOCAL.ALL_OBJECTS = {}
# ---> 49   LOCAL.GENERATED_WITH_V2 = tf.__internal__.tf2.enabled()
#      50
#      51   # Compatibility aliases (need to exist in both V1 and V2).
#
# AttributeError: module 'tensorflow.compat.v2.__internal__' has no attribute 'tf2'

# %% [markdown]
# **Reading the image files**

# %%
dire='/content/drive/MyDrive/Colab Notebooks/flower recognition/data'
categories=['dandelion', 'daisy', 'sunflowers', 'tulips', 'roses', 'Buttercup']

# %%
features=[]
for i in categories:
    path=os.path.join(dire,i)
    num_classes=categories.index(i)
    for img in os.listdir(path):
        if img.endswith('.jpg'): 
            img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_COLOR)
            img_array=cv2.resize(img_array,(150,150))
            features.append([img_array,num_classes])

# %%
X=[]
y=[]
for i,j in features:
    X.append(i)
    y.append(j)

# %% [markdown]
# **Example of flower images per class**

# %%
fig,ax=plt.subplots(2,6)
fig.set_size_inches(15,15)
for i in range(2):
    for j in range (6):
        l=np.random.randint(0,len(y))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+categories[y[l]])
plt.axis('off')        
plt.tight_layout()

# %% [markdown]
# Reshaping and normalizing: the need of resizing the feature vetcor x is to meet the keras requirement and normalization is done to scale all the values in a similar range¶

# %%
X=np.array(X).reshape(-1,150,150,3)/255.0

# %% [markdown]
# **Class destribution**

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(14,7))
fig=sns.countplot(y)
fig.set(xticks=range(len(categories)), xticklabels=[i for i in categories])
plt.xlabel('FLOWER SPECIES')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
list_dandelion=len([i for i in y if i==0])
list_daisy=len([i for i in y if i==1])
list_sunflower=len([i for i in y if i==2])
list_tulip=len([ i for i in y if i==3])
list_rose=len([i for i in y if i==4])
list_buttercup = len([i for i in y if i==5])
list_species=[list_dandelion,list_daisy,list_sunflower,list_tulip,list_rose,list_buttercup]

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(18,10))
plt.pie(list_species,labels=categories,startangle=90,colors=['r','g','b','y','m','#99ff99'],autopct='%1.1f%%',explode = (0, 0.1, 0, 0,0,0),shadow=True)
plt.legend()
plt.show()

# %%
from keras.utils import to_categorical
y=to_categorical(y)

# %% [markdown]
# **Train Test split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=12)

# %%
print("Shape of x_train", x_train.shape)
print("Shape of y_train", y_train.shape)
print("Shape of x_test", x_test.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of x_train (3052, 150, 150, 3)
# Shape of y_train (3052, 6)
# Shape of x_test (764, 150, 150, 3)
# Shape of y_test (764, 6)

# %% [markdown]
# **CNN Model**

# %%
def cnn_model(input_shape):
  model = Sequential()
  model.add(Conv2D(32, (3, 3), input_shape=(input_shape)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Conv2D(64, (3, 3)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Conv2D(128, (3, 3)))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(2, 2, padding="same"))
  model.add(Dropout(0.2))
  
  model.add(Flatten())
  
  model.add(Dense(512, activation="relu"))
  
  model.add(Dropout(0.2))
  model.add(Dense(128, activation="relu"))
  model.add(Dropout(0.2))
  model.add(Dense(6, activation="softmax"))

  model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
  
  return model

# %% [markdown]
# **Augmentation to avoid overfitting**

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images
datagen.fit(x_train)

# %% [markdown]
# **Callbacks**

# %%
keras.backend.clear_session()
#callback function for early stopping

accuracy_threshold = 0.99999

class myCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
      if(logs.get('accuracy')>99.99):
        print("\nReached %2.2f%% accuracy so we will stop trianing" % (accuracy_threshold*100))
        self.model.stop_training = True

acc_callback = myCallback()

checkpoint_path = '/content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5'
epochs=50

callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

# %%
#define a function to fit the model
def fit_and_evaluate(t_x, val_x, t_y, val_y, EPOCHS=50, BATCH_SIZE=128):
    model = None
    input_shape = 150,150,3
    model = cnn_model(input_shape)
    results = model.fit_generator(datagen.flow(t_x, t_y, batch_size=BATCH_SIZE),
                              epochs = EPOCHS, validation_data = (val_x,val_y),
                              callbacks= callbacks,
                              verbose = 1, steps_per_epoch= t_x.shape[0] // 128)
    
    print("Val Score: ", model.evaluate(val_x, val_y))
    return results

# %%
n_folds=5
epochs = 50
batch_size = 128

model_history = [] 

for i in range(n_folds):
    print("Training on Fold: ",i+1)
    t_x, val_x, t_y, val_y = train_test_split(x_train, y_train, test_size=0.1, 
                                               random_state = np.random.randint(1,1000, 1)[0])
    model_history.append(fit_and_evaluate(t_x, val_x, t_y, val_y, epochs, batch_size))
    print("======="*12, end="\n\n\n")
# Out:
# Training on Fold:  1
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if __name__ == '__main__':
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 2.0311 - accuracy: 0.2120
# Epoch 1: val_loss improved from inf to 1.68094, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 41s 2s/step - loss: 2.0311 - accuracy: 0.2120 - val_loss: 1.6809 - val_accuracy: 0.3203 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.5258 - accuracy: 0.3560
# Epoch 2: val_loss improved from 1.68094 to 1.39878, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 16s 748ms/step - loss: 1.5258 - accuracy: 0.3560 - val_loss: 1.3988 - val_accuracy: 0.4706 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3807 - accuracy: 0.4121
# Epoch 3: val_loss improved from 1.39878 to 1.27075, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 14s 658ms/step - loss: 1.3807 - accuracy: 0.4121 - val_loss: 1.2707 - val_accuracy: 0.4935 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2702 - accuracy: 0.4614
# Epoch 4: val_loss improved from 1.27075 to 1.18438, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 16s 766ms/step - loss: 1.2702 - accuracy: 0.4614 - val_loss: 1.1844 - val_accuracy: 0.5131 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2102 - accuracy: 0.4973
# Epoch 5: val_loss did not improve from 1.18438
# 21/21 [==============================] - 14s 674ms/step - loss: 1.2102 - accuracy: 0.4973 - val_loss: 1.2061 - val_accuracy: 0.5490 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 1.
- val_accuracy: 0.7974 - lr: 1.0000e-04
# Epoch 40/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5533 - accuracy: 0.7983
# Epoch 40: val_loss did not improve from 0.66132
# 21/21 [==============================] - 12s 576ms/step - loss: 0.5533 - accuracy: 0.7983 - val_loss: 0.6804 - val_accuracy: 0.7843 - lr: 1.0000e-04
# Epoch 41/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5391 - accuracy: 0.7880
# Epoch 41: val_loss did not improve from 0.66132
# 21/21 [==============================] - 14s 647ms/step - loss: 0.5391 - accuracy: 0.7880 - val_loss: 0.6643 - val_accuracy: 0.7941 - lr: 1.0000e-04
# Epoch 42/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5473 - accuracy: 0.8002
# Epoch 42: val_loss did not improve from 0.66132
# 21/21 [==============================] - 14s 646ms/step - loss: 0.5473 - accuracy: 0.8002 - val_loss: 0.6677 - val_accuracy: 0.7974 - lr: 1.0000e-04
# Epoch 43/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5448 - accuracy: 0.7880
# Epoch 43: val_loss improved from 0.66132 to 0.65906, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 15s 700ms/step - loss: 0.5448 - accuracy: 0.7880 - val_loss: 0.6591 - val_accuracy: 0.7974 - lr: 1.0000e-04
# Epoch 44/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5424 - accuracy: 0.8018
# Epoch 44: val_loss did not improve from 0.65906
# 21/21 [==============================] - 13s 601ms/step - loss: 0.5424 - accuracy: 0.8018 - val_loss: 0.6836 - val_accuracy: 0.7810 - lr: 1.0000e-04
# Epoch 45/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5306 - accuracy: 0.8025
# Epoch 45: val_loss did not improve from 0.65906
# 21/21 [==============================] - 14s 642ms/step - loss: 0.5306 - accuracy: 0.8025 - val_loss: 0.6667 - val_accuracy: 0.8039 - lr: 1.0000e-04
# Epoch 46/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5330 - accuracy: 0.7995
# Epoch 46: val_loss improved from 0.65906 to 0.65689, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 15s 703ms/step - loss: 0.5330 - accuracy: 0.7995 - val_loss: 0.6569 - val_accuracy: 0.8007 - lr: 1.0000e-04
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5305 - accuracy: 0.8044
# Epoch 47: val_loss did not improve from 0.65689
# 21/21 [==============================] - 13s 607ms/step - loss: 0.5305 - accuracy: 0.8044 - val_loss: 0.6704 - val_accuracy: 0.7974 - lr: 1.0000e-04
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.8071
# Epoch 48: val_loss did not improve from 0.65689
# 21/21 [==============================] - 12s 576ms/step - loss: 0.5166 - accuracy: 0.8071 - val_loss: 0.6712 - val_accuracy: 0.7941 - lr: 1.0000e-04
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.8040
# Epoch 49: val_loss did not improve from 0.65689
# 21/21 [==============================] - 12s 581ms/step - loss: 0.5208 - accuracy: 0.8040 - val_loss: 0.6668 - val_accuracy: 0.7974 - lr: 1.0000e-04
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.8117
# Epoch 50: val_loss improved from 0.65689 to 0.64977, saving model to /content/drive/MyDrive/Colab Notebooks/flower recognition/kfold-cnn.h5
# 21/21 [==============================] - 15s 715ms/step - loss: 0.5107 - accuracy: 0.8117 - val_loss: 0.6498 - val_accuracy: 0.7974 - lr: 1.0000e-04
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6498 - accuracy: 0.7974
# Val Score:  [0.6497704386711121, 0.7973856329917908]
# ====================================================================================
#
#
# Training on Fold:  2
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 2.1383 - accuracy: 0.1963
# Epoch 1: val_loss did not improve from 0.64977
# 21/21 [==============================] - 15s 655ms/step - loss: 2.1383 - accuracy: 0.1963 - val_loss: 1.6814 - val_accuracy: 0.3431 - lr: 0.0010
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.5722 - accuracy: 0.3377
# Epoch 2: val_loss did not improve from 0.64977
# 21/21 [==============================] - 12s 584ms/step - loss: 1.5722 - accuracy: 0.3377 - val_loss: 1.4384 - val_accuracy: 0.4542 - lr: 0.0010
# Epoch 3/50
# 21/21 [==============================] - ETA: 0s - loss: 1.4026 - accuracy: 0.4332
# Epoch 3: val_loss did not improve from 0.64977
# 21/21 [==============================] - 12s 577ms/step - loss: 1.4026 - accuracy: 0.4332 - val_loss: 1.2816 - val_accuracy: 0.4673 - lr: 0.0010
# Epoch 4/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2958 - accuracy: 0.4629
# Epoch 4: val_loss did not improve from 0.64977
# 21/21 [==============================] - 13s 635ms/step - loss: 1.2958 - accuracy: 0.4629 - val_loss: 1.2264 - val_accuracy: 0.4902 - lr: 0.0010
# Epoch 5/50
# 21/21 [==============================] - ETA: 0s - loss: 1.2263 - accuracy: 0.5037
# Epoch 5: val_loss did not improve from 0.64977
# 21/21 [==============================] - 14s 650ms/step - loss: 1.2263 - accuracy: 0.5037 - val_loss: 1.1596 - val_accuracy: 0.5425 - lr: 0.0010
# Epoch 6/50
# 21/21 [==============================] - ETA: 0s - loss: 1.
# 10/10 [==============================] - 0s 15ms/step - loss: 0.7520 - accuracy: 0.7353
# Val Score:  [0.7520159482955933, 0.7352941036224365]
# ====================================================================================
#
#
# Training on Fold:  3

# %%
plt.title('Train Accuracy vs Val Accuracy')
plt.plot(model_history[0].history['acc'], label='Train Accuracy Fold 1', color='black')
plt.plot(model_history[0].history['val_acc'], label='Val Accuracy Fold 1', color='black', linestyle = "dashdot")
plt.plot(model_history[1].history['acc'], label='Train Accuracy Fold 2', color='red', )
plt.plot(model_history[1].history['val_acc'], label='Val Accuracy Fold 2', color='red', linestyle = "dashdot")
plt.plot(model_history[2].history['acc'], label='Train Accuracy Fold 3', color='green', )
plt.plot(model_history[2].history['val_acc'], label='Val Accuracy Fold 3', color='green', linestyle = "dashdot")
plt.legend()
plt.show()

# %%
'''''

# %%
k = 6
cross_val = KFold(k, shuffle=True, random_state=1)
fold_count = 1

# For loss & acc plotting
histories = []

# For testing/evaluation acc scores
eval_scores = []

input_shape = (150,150,3)

# # For callbacks
# es_callbacks = keras.callbacks.EarlyStopping(monitor="val_loss",
#                                           mode="min",
#                                           verbose=1,
#                                           patience=4)

# %%
for train, validation in cross_val.split(X):
    print("="*80)
    # print("Fold-{}".format(fold_count))
    print("-"*80)
    print("Training & Validation")
    # fold_count = fold_count + 1
    
    model = sequential_model(input_shape)
    
    # X_train, y_train = X[train], y[train]
    # X_val, y_val = X[validation], y[validation]
    
    history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=128),
                              epochs = 50, validation_data = (x_test,y_test),
                              callbacks=callbacks,
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128)
    
    print("-"*80)
    print("Testing/evaluation")
    eval_loss, eval_accuracy = model.evaluate(x_test,y_test)
    
    histories.append(history)
    eval_scores.append(eval_accuracy)
    print("_"*80)

# %%
CNN_history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=128),
                              epochs = epochs, validation_data = (x_test,y_test),
                              callbacks=callbacks,
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(CNN_history.history['loss'])
plt.plot(CNN_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(CNN_history.history['accuracy'])
plt.plot(CNN_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
preds=model.predict(x_test)
predictions=np.argmax(preds,axis=1)

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, predictions))

# %%
def report_generate(Y_test, predictions):
  report = pd.DataFrame(classification_report(y_true = Y_test, y_pred = predictions, output_dict=True)).transpose()
  report = report.rename(index={'0': 'dandelion','1':'daisy','2':'sunflowers','3':'tulips', '4':'roses'})
  report[['precision','recall','f1-score']]=report[['precision','recall','f1-score']].apply(lambda x: round(x*100,2))
  report=report.drop(["support"],axis=1)
  columns = ['precision','recall','f1-score']
  report.columns = columns
  plt = report.plot(kind='bar',figsize=(12,6))
  
  plot=plt.tick_params(rotation=40)
  
  return plot,report

# %%
report_generate(Y_test, predictions)

# %%
#confusion matrix
def conf_matrix(Y_test, y_pred):

  cm = confusion_matrix(Y_test, y_pred) 
# Transform to df for easier plotting
  
  cm_df = pd.DataFrame(cm,
                       index = ['dandelion', 'daisy', 'sunflowers', 'tulips', 'roses'], 
                       columns = ['dandelion', 'daisy', 'sunflowers', 'tulips', 'roses'])
  plt.figure(figsize=(10,7))
  sns.heatmap(cm_df, annot=True,cmap="YlGnBu", fmt='g')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.xticks(rotation = 45)
  plt.yticks(rotation = 45)
  plt.show()
  plt.close()

# %%
conf_matrix(Y_test,predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()

# %%
correct_class=[]
incorrect_class=[]
i=0
for i in range(len(y_test)):
    if(np.argmax(y_test[i])==predictions[i]):
        correct_class.append(i)
    if(len(correct_class)==8):
        break

count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range (4):
    for j in range (2):
        ax[i,j].imshow(x_test[correct_class[count]])
        ax[i,j].set_title("Predicted Flower : "+ categories[predictions[correct_class[count]]] +"\n"+"Actual Flower : "+ categories[np.argmax(y_test[correct_class[count]])])
        plt.tight_layout()
        count+=1

# %%
i=0
for i in range(len(y_test)):
    
    if (np.argmax(y_test[i])!=predictions[i]):
        
        incorrect_class.append(i)
    if (len(incorrect_class)==8):
        break

# %%
count=0
fig,ax=plt.subplots(4,2)
fig.set_size_inches(15,15)
for i in range(4):
    for j in range(2):
        ax[i,j].imshow(x_test[incorrect_class[count]])
        ax[i,j].set_title("Predicted flower : " + categories[predictions[incorrect_class[count]]] + "\n"+"Actual Flower : " +categories[np.argmax(y_test[incorrect_class[count]])])
        plt.tight_layout()
        count+=1

# %%
import requests
from PIL import Image
from io import BytesIO

def process_image(url):
    response=requests.get(url)
    img=Image.open(BytesIO(response.content))
    fix,ax=plt.subplots(1,3,figsize=(15,20))
    ax[0].imshow(img)
    ax[0].set_title('image')
    
    #grayscale and normalization
    img=np.array(img)
    img=cv2.cvtColor(img,cv2.IMREAD_COLOR)
    print(img.shape)
    img=img/255.0
    ax[1].imshow(img)
    ax[1].set_title('color image')
    
    #resizing
    img=cv2.resize(img,(150,150))
    print(img.shape)
    ax[2].imshow(img)
    ax[2].set_title('predicted image')
    plt.tight_layout()
    img=np.expand_dims(img,axis=0)
    #making it model ready
    
    print(img.shape)
    return img


    
def predict(url):
    img=process_image(url)
    label=model.predict(img)
    final_1=np.argmax(label,axis=1)[0]
    plt.xlabel(categories[final_1])
    return categories[final_1]

# %%
predict("https://images.pexels.com/photos/1883385/pexels-photo-1883385.jpeg?auto=compress&cs=tinysrgb&w=600")

# %% [markdown]
# **VGG16 Model**

# %%
from keras.applications import VGG16
Base_model = VGG16(include_top= False, weights='imagenet',input_shape=(150,150,3), pooling='avg')
VGG16_model = Sequential()

VGG16_model.add(Base_model)
VGG16_model.add(Dense(256,activation='relu'))
# adding prediction(softmax) layer
VGG16_model.add(Dense(5,activation="softmax"))
VGG16_model.summary()

# %%
VGG16_model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
checkpoint_path = '/content/drive/MyDrive/Colab Notebooks/flower recognition/VGG16.h5'
callbacks = [
    EarlyStopping(monitor='val_loss', mode='min', patience=15, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.1, patience=5, min_lr=0.000001, verbose=1),
    ModelCheckpoint(monitor='val_loss', mode='min', filepath=checkpoint_path, verbose=1, save_best_only=True, save_weights_only=False),
    acc_callback
]

VGG16_history = VGG16_model.fit_generator(datagen.flow(x_train,y_train, batch_size=128),
                              epochs = 100, validation_data = (x_test,y_test),
                              callbacks=callbacks,
                              verbose = 1, steps_per_epoch=x_train.shape[0] // 128)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(VGG16_history.history['loss'])
plt.plot(VGG16_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

sns.set_style('whitegrid')
plt.figure(figsize=(12,5))
plt.plot(VGG16_history.history['accuracy'])
plt.plot(VGG16_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
vgg_preds=VGG16_model.predict(x_test)
VGG16_model_predictions=np.argmax(vgg_preds,axis=1)

# %%
from sklearn.metrics import classification_report
Y_test =np.argmax(y_test,axis=1)
print(classification_report(Y_test, VGG16_model_predictions))

# %%
report_generate(Y_test, VGG16_model_predictions)

# %%
conf_matrix(Y_test,VGG16_model_predictions)

# %%
# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(categories):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)

print('ROC AUC score:', multiclass_roc_auc_score(Y_test,VGG16_model_predictions))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
